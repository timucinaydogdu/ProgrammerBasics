# %% [markdown]
# # Mechine Learning
#
# ## Python Basics (Detailled)

# %% [markdown]
# #### Tab function and comment
#
# Tab : Tab fun make program borders and limits.
#
# Comments : Python have just one line comment syntax(#). """~~~""" this not be multiline comment. Just sort time solution.

# %% [markdown]
# #### Variables
#
# Variables : variables are similar x,y,z in math. They take many difrent valur and characters. <br>
#
# * Casting : Casting is a predata type identifier. <br>
#     x = int(7) <br>
#     y = str(7)  # Used str predata type dont be need to ("~~~") syntax. <br>
# * Type : Use for get data type information function. <br>
#     print(type(x))  # return to data type information on terminal.

# %% [markdown]
# #### Name Rules
#
# * Start with letter character and underline
# * Dont use numbers at firsth character
# * Dont use special characters
# * Care about key sensetive
# * Dont use python special names. <br>
#
# ##### Named fortmats
# * myName (Camelcase)
# * MyName (Pascalcase)
# * my_name(Sneakecase)<br>
# Pick one and use all time.
